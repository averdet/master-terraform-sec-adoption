# %%
from datetime import datetime
from git import Repo, Git
import subprocess
import os
import csv

filename = "C:\\Users\\leu_m\\PycharmProjects\\master-terraform-sec-adoption\\azure\\csv\\azure-analysis-tfsec.csv"

METRICS_FILE = "C:\\Users\\leu_m\\PycharmProjects\\master-terraform-sec-adoption\\azure\\csv\\azure_dataset_metrics.csv"
STAR_FILTERED_REPOS = "C:\\Users\\leu_m\\PycharmProjects\\master-terraform-sec-adoption\\azure\\csv\\azure_dataset_filtered.csv"
INPUT_FILE = "C:\\Users\\leu_m\\PycharmProjects\\master-terraform-sec-adoption\\azure\\csv\\azure_results_tfsec.csv"
PATH_OF_TMP_DIRECTORY = "C:\\Users\\leu_m\\PycharmProjects\\master-terraform-sec-adoption\\tmp\\azure"

stars_by_projects = {}
forks_by_projects = {}
contrib_by_projects = {}

with open(STAR_FILTERED_REPOS, 'r') as f:
    tmp_repo_names = f.readlines()
repo_names = [k.strip("\n") for k in tmp_repo_names]

with open(METRICS_FILE, 'r') as f:
    #f.readline()
    rows = f.readlines()
    for item in rows:
        column = item.split(',')
        if column[0] in repo_names:
            stars_by_projects[column[0]] = int(column[1])
            forks_by_projects[column[0]] = int(column[2])
            contrib_by_projects[column[0]] = int(column[3].strip("\n"))

with open(INPUT_FILE, 'r') as f:
    f.readline()
    repo_results = f.readlines()

repo_stars_mine = {}
with open(METRICS_FILE, 'r') as f:
    f.readline()
    rows = f.readlines()
    for item in rows:
        column = item.split(',')
        if column[0] in repo_names:
            repo_stars_mine[column[0]] = column[1]

stars_passed_rate_mine = {}
for row in repo_results:
    columns = row.split(',')
    repo_name = columns[0]
    if repo_name in repo_stars_mine:
        passed_count = len(columns[3].split(';'))
        failed_count = len(columns[4].split(';'))
        if passed_count + failed_count > 0:
            stars_passed_rate_mine[repo_name] = passed_count/(passed_count+failed_count) 

def get_commit_count_until_hash(repo_name):
    try:
        # Create the directory if it doesn't exist
        if not os.path.exists(PATH_OF_TMP_DIRECTORY):
            os.makedirs(PATH_OF_TMP_DIRECTORY)
        
        # Change directory to the specified directory
        os.chdir(PATH_OF_TMP_DIRECTORY)
        
        # Clone the repository
        repo_url = "https://github.com/"+repo_name+".git"
        subprocess.run(["git", "clone", repo_url])
        repo_name = str(repo_name.split("/")[1]).replace(".git","")
        
        # Change directory to the cloned repository
        os.chdir(os.path.join(PATH_OF_TMP_DIRECTORY, repo_name))
        
        commit_hash = get_closest_commit(os.path.join(PATH_OF_TMP_DIRECTORY, repo_name), datetime(2023, 2, 20))
        
        # Fetch all commits and count them
        output = subprocess.check_output(["git", "rev-list", "--count", commit_hash]).decode("utf-8").strip()
        commit_count = int(output)
        
        output = subprocess.check_output(["git", "log", "--format=%aN", commit_hash]).decode("utf-8")
        contributors = len(set(output.splitlines()))
        
        return commit_count, contributors
    
    except subprocess.CalledProcessError as e:
        print("Error:", e)
        return None

def get_closest_commit(repo_path, target_date):
    git = Git(repo_path)

    # Use rev-list to find the closest commit to the target date
    closest_commit_hash = git.rev_list('-n', '1', '--before={:%Y-%m-%d %H:%M:%S}'.format(target_date), '--all')

    return closest_commit_hash

with open(filename, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(["project_name", "stars_passed", "stars", "forks", "contributors", "commits", "commiters"])
        for row in stars_passed_rate_mine.keys():
            try:
                report = get_commit_count_until_hash(row)
                commit_count = report[0]
                contributors = report[1]
                
                if commit_count is None:
                    commit_count = 0
                    
                if contributors is None:
                    contributors = 0
                    
                csv_writer.writerow([row, stars_passed_rate_mine.get(row), stars_by_projects.get(row), 
                                    forks_by_projects.get(row), contrib_by_projects.get(row), commit_count, contributors])
            except Exception as e:
                print(row)
# Out:
# Azure/FTALive-Sessions
# FrenchBarbusCorp/Workshop-Azure-Container-Apps

# %%
import csv
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd

filename = "C:\\Users\\leu_m\\PycharmProjects\\master-terraform-sec-adoption\\azure\\csv\\azure-analysis-tfsec.csv"

# Sample DataFrame
data = pd.read_csv(filename)

# Create DataFrame
df = pd.DataFrame(data)

# Function to map passed rate to categories
def map_passed_rate(passed_rate):
    if passed_rate < 0.3:
        return "LOW_RATE"
    #elif passed_rate < 0.4:
    #    return "LOW_RATE"
    elif passed_rate < 0.6:
        return "MEDIUM_RATE"
    #elif passed_rate < 0.8:
     #   return "HIGH_RATE"
    else:
        return "HIGH_RATE"

    # Function to map other continuous variables to categories based on min-max normalization
def map_to_categories(value, min_val, max_val, category):
    if value < min_val + 0.1 * (max_val - min_val):
        return "VERY_LOW_"+category
    elif value < min_val + 0.2 * (max_val - min_val):
        return "LOW_"+category
    elif value < min_val + 0.3 * (max_val - min_val):
        return "MODERATE_"+category
    elif value < min_val + 0.4 * (max_val - min_val):
        return "BELOW_AVERAGE_"+category
    elif value < min_val + 0.5 * (max_val - min_val):
        return "AVERAGE_"+category
    elif value < min_val + 0.6 * (max_val - min_val):
        return "ABOVE_AVERAGE_"+category
    elif value < min_val + 0.7 * (max_val - min_val):
        return "HIGH_"+category
    elif value < min_val + 0.8 * (max_val - min_val):
        return "VERY_HIGH_"+category
    elif value < min_val + 0.9 * (max_val - min_val):
        return "EXTREMELY_HIGH_"+category
    else:
        return "EXCEPTIONALLY_HIGH_"+category

# Transforming passed rate
df['passed_rate_category'] = df['stars_passed'].apply(map_passed_rate)

# Transforming stars, forks, and contributors
for col in ['stars', 'forks', 'commits', 'commiters']:
    min_val = df[col].min()
    max_val = df[col].max()
    df[col + '_category'] = df[col].apply(lambda x: map_to_categories(x, min_val, max_val, col))

# Print the transformed DataFrame
#print(df.columns)

print(df[['passed_rate_category', 'stars_category', 'forks_category', 'commits_category', 'commiters_category']])

aux = df[['passed_rate_category', 'stars_category', 'forks_category', 'commits_category', 'commiters_category']]

transactions = aux.values

print(transactions)

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_selected = pd.DataFrame(te_ary, columns=te.columns_)

# Generate frequent itemsets with minimum support of 0.3
frequent_itemsets = apriori(df_selected, min_support=0.3, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Print the rules
for index, rule in rules.iterrows():
    antecedents = ', '.join(rule['antecedents'])
    consequents = ', '.join(rule['consequents'])
    print(f"Rule: {antecedents} -> {consequents}")
    print(f"Support: {rule['support']}")
    print(f"Confidence: {rule['confidence']}")
    print(f"Lift: {rule['lift']}")
    print()
    

filename = "C:\\Users\\leu_m\\PycharmProjects\\master-terraform-sec-adoption\\rq3\\report-azure-tfsec.csv"

with open(filename, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(["antecedents", "consequents", "Support", "Confidence", "Lift"])
        for index, rule in rules.iterrows():
            antecedents = ', '.join(rule['antecedents'])
            consequents = ', '.join(rule['consequents'])
            csv_writer.writerow([antecedents, consequents, rule['support'], rule['confidence'], rule['lift']])
# Out:
#     passed_rate_category            stars_category  forks_category  \
# 0            MEDIUM_RATE  EXCEPTIONALLY_HIGH_stars       LOW_forks
# 1            MEDIUM_RATE       BELOW_AVERAGE_stars       LOW_forks
# 2            MEDIUM_RATE       BELOW_AVERAGE_stars  MODERATE_forks
# 3            MEDIUM_RATE       BELOW_AVERAGE_stars  MODERATE_forks
# 4            MEDIUM_RATE            MODERATE_stars  VERY_LOW_forks
# ..                   ...                       ...             ...
# 128          MEDIUM_RATE            VERY_LOW_stars  VERY_LOW_forks
# 129          MEDIUM_RATE            VERY_LOW_stars  VERY_LOW_forks
# 130          MEDIUM_RATE            VERY_LOW_stars  VERY_LOW_forks
# 131          MEDIUM_RATE            VERY_LOW_stars  VERY_LOW_forks
# 132          MEDIUM_RATE            VERY_LOW_stars  VERY_LOW_forks
#
#      commits_category            commiters_category
# 0    VERY_LOW_commits             AVERAGE_commiters
# 1    VERY_LOW_commits            MODERATE_commiters
# 2    VERY_LOW_commits            VERY_LOW_commiters
# 3         LOW_commits  EXCEPTIONALLY_HIGH_commiters
# 4    VERY_LOW_commits            VERY_LOW_commiters
# ..                ...                           ...
# 128  VERY_LOW_commits            VERY_LOW_commiters
# 129  VERY_LOW_commits            VERY_LOW_commiters
# 130  VERY_LOW_commits            VERY_LOW_commiters
# 131  VERY_LOW_commits            VERY_LOW_commiters
# 132  VERY_LOW_commits                 LOW_commiters
#
# [133 rows x 5 columns]
# [['MEDIUM_RATE' 'EXCEPTIONALLY_HIGH_stars' 'LOW_forks' 'VERY_LOW_commits'
#   'AVERAGE_commiters']
#  ['MEDIUM_RATE' 'BELOW_AVERAGE_stars' 'LOW_forks' 'VERY_LOW_commits'
#   'MODERATE_commiters']
#  ['MEDIUM_RATE' 'BELOW_AVERAGE_stars' 'MODERATE_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'BELOW_AVERAGE_stars' 'MODERATE_forks' 'LOW_commits'
#   'EXCEPTIONALLY_HIGH_commiters']
#  ['MEDIUM_RATE' 'MODERATE_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'MODERATE_stars' 'MODERATE_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'LOW_stars' 'BELOW_AVERAGE_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'MODERATE_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'MODERATE_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'BELOW_AVERAGE_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'EXCEPTIONALLY_HIGH_forks'
#   'VERY_LOW_commits' 'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'LOW_commits'
#   'BELOW_AVERAGE_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks'
#   'EXCEPTIONALLY_HIGH_commits' 'HIGH_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'MODERATE_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'MODERATE_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'LOW_commits'
#   'MODERATE_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'LOW_commits'
#   'AVERAGE_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'BELOW_AVERAGE_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'MODERATE_commits'
#   'BELOW_AVERAGE_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'MODERATE_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'LOW_commits'
#   'MODERATE_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['HIGH_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['LOW_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']]
# Rule: VERY_LOW_forks -> HIGH_RATE
# Support: 0.3007518796992481
# Confidence: 0.31746031746031744
# Lift: 1.029810298102981
#
# Rule: HIGH_RATE -> VERY_LOW_forks
# Support: 0.3007518796992481
# Confidence: 0.975609756097561
# Lift: 1.029810298102981
#
# Rule: MEDIUM_RATE -> VERY_LOW_stars
# Support: 0.5263157894736842
# Confidence: 0.9333333333333332
# Lift: 1.0010752688172042
#
# Rule: VERY_LOW_stars -> MEDIUM_RATE
# Support: 0.5263157894736842
# Confidence: 0.5645161290322581
# Lift: 1.0010752688172044
#
# Rule: VERY_LOW_commits -> VERY_LOW_commiters
# Support: 0.6992481203007519
# Confidence: 0.7500000000000001
# Lift: 1.0611702127659577
#
# Rule: VERY_LOW_commiters -> VERY_LOW_commits
# Support: 0.6992481203007519
# Confidence: 0.9893617021276596
# Lift: 1.0611702127659575
#
# Rule: VERY_LOW_forks -> VERY_LOW_commiters
# Support: 0.6766917293233082
# Confidence: 0.7142857142857143
# Lift: 1.0106382978723405
#
# Rule: VERY_LOW_commiters -> VERY_LOW_forks
# Support: 0.6766917293233082
# Confidence: 0.9574468085106383
# Lift: 1.0106382978723405
#
# Rule: VERY_LOW_commiters -> VERY_LOW_stars
# Support: 0.6691729323308271
# Confidence: 0.946808510638298
# Lift: 1.015528483184626
#
# Rule: VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.6691729323308271
# Confidence: 0.717741935483871
# Lift: 1.015528483184626
#
# Rule: VERY_LOW_forks -> VERY_LOW_commits
# Support: 0.8872180451127819
# Confidence: 0.9365079365079365
# Lift: 1.0044802867383513
#
# Rule: VERY_LOW_commits -> VERY_LOW_forks
# Support: 0.8872180451127819
# Confidence: 0.9516129032258065
# Lift: 1.0044802867383513
#
# Rule: VERY_LOW_commits -> VERY_LOW_stars
# Support: 0.8721804511278195
# Confidence: 0.9354838709677419
# Lift: 1.0033818938605619
#
# Rule: VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.8721804511278195
# Confidence: 0.9354838709677419
# Lift: 1.0033818938605619
#
# Rule: VERY_LOW_forks -> VERY_LOW_stars
# Support: 0.924812030075188
# Confidence: 0.9761904761904763
# Lift: 1.0470430107526882
#
# Rule: VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.924812030075188
# Confidence: 0.9919354838709677
# Lift: 1.0470430107526882
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_commiters
# Support: 0.39097744360902253
# Confidence: 0.753623188405797
# Lift: 1.0662966389145851
#
# Rule: MEDIUM_RATE, VERY_LOW_commiters -> VERY_LOW_commits
# Support: 0.39097744360902253
# Confidence: 0.9811320754716981
# Lift: 1.0523432744978698
#
# Rule: VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_commiters
# Support: 0.39097744360902253
# Confidence: 0.41935483870967744
# Lift: 1.0523432744978698
#
# Rule: VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.39097744360902253
# Confidence: 0.5531914893617021
# Lift: 1.0662966389145851
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters -> MEDIUM_RATE
# Support: 0.38345864661654133
# Confidence: 0.5666666666666667
# Lift: 1.0048888888888887
#
# Rule: VERY_LOW_forks, MEDIUM_RATE -> VERY_LOW_commiters
# Support: 0.38345864661654133
# Confidence: 0.7285714285714285
# Lift: 1.0308510638297872
#
# Rule: MEDIUM_RATE, VERY_LOW_commiters -> VERY_LOW_forks
# Support: 0.38345864661654133
# Confidence: 0.9622641509433962
# Lift: 1.0157232704402517
#
# Rule: VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_commiters
# Support: 0.38345864661654133
# Confidence: 0.40476190476190477
# Lift: 1.0157232704402517
#
# Rule: VERY_LOW_commiters -> VERY_LOW_forks, MEDIUM_RATE
# Support: 0.38345864661654133
# Confidence: 0.5425531914893617
# Lift: 1.0308510638297872
#
# Rule: MEDIUM_RATE -> VERY_LOW_forks, VERY_LOW_commiters
# Support: 0.38345864661654133
# Confidence: 0.6799999999999999
# Lift: 1.004888888888889
#
# Rule: MEDIUM_RATE, VERY_LOW_commiters -> VERY_LOW_stars
# Support: 0.38345864661654133
# Confidence: 0.9622641509433962
# Lift: 1.0321059038344493
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.38345864661654133
# Confidence: 0.7285714285714285
# Lift: 1.0308510638297872
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> MEDIUM_RATE
# Support: 0.38345864661654133
# Confidence: 0.5730337078651685
# Lift: 1.0161797752808988
#
# Rule: MEDIUM_RATE -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.38345864661654133
# Confidence: 0.6799999999999999
# Lift: 1.0161797752808988
#
# Rule: VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.38345864661654133
# Confidence: 0.5425531914893617
# Lift: 1.0308510638297872
#
# Rule: VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commiters
# Support: 0.38345864661654133
# Confidence: 0.4112903225806452
# Lift: 1.0321059038344493
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_stars
# Support: 0.48872180451127817
# Confidence: 0.9420289855072462
# Lift: 1.010402057035998
#
# Rule: VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.48872180451127817
# Confidence: 0.5241935483870968
# Lift: 1.010402057035998
#
# Rule: VERY_LOW_forks, MEDIUM_RATE -> VERY_LOW_stars
# Support: 0.518796992481203
# Confidence: 0.9857142857142858
# Lift: 1.0572580645161291
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.518796992481203
# Confidence: 0.9857142857142858
# Lift: 1.0404761904761906
#
# Rule: VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.518796992481203
# Confidence: 0.5476190476190477
# Lift: 1.0404761904761906
#
# Rule: VERY_LOW_stars -> VERY_LOW_forks, MEDIUM_RATE
# Support: 0.518796992481203
# Confidence: 0.5564516129032259
# Lift: 1.0572580645161291
#
# Rule: VERY_LOW_forks, VERY_LOW_commits -> VERY_LOW_commiters
# Support: 0.6691729323308271
# Confidence: 0.7542372881355933
# Lift: 1.0671655247024885
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters -> VERY_LOW_commits
# Support: 0.6691729323308271
# Confidence: 0.9888888888888889
# Lift: 1.060663082437276
#
# Rule: VERY_LOW_commits, VERY_LOW_commiters -> VERY_LOW_forks
# Support: 0.6691729323308271
# Confidence: 0.956989247311828
# Lift: 1.0101553166069297
#
# Rule: VERY_LOW_forks -> VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.6691729323308271
# Confidence: 0.7063492063492064
# Lift: 1.0101553166069295
#
# Rule: VERY_LOW_commits -> VERY_LOW_forks, VERY_LOW_commiters
# Support: 0.6691729323308271
# Confidence: 0.717741935483871
# Lift: 1.060663082437276
#
# Rule: VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_commits
# Support: 0.6691729323308271
# Confidence: 0.946808510638298
# Lift: 1.0671655247024885
#
# Rule: VERY_LOW_commits, VERY_LOW_commiters -> VERY_LOW_stars
# Support: 0.6616541353383458
# Confidence: 0.9462365591397849
# Lift: 1.01491501907735
#
# Rule: VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.6616541353383458
# Confidence: 0.7586206896551724
# Lift: 1.0733675715333824
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.6616541353383458
# Confidence: 0.9887640449438202
# Lift: 1.0605291772381298
#
# Rule: VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.6616541353383458
# Confidence: 0.7096774193548387
# Lift: 1.0605291772381298
#
# Rule: VERY_LOW_commiters -> VERY_LOW_commits, VERY_LOW_stars
# Support: 0.6616541353383458
# Confidence: 0.9361702127659575
# Lift: 1.0733675715333824
#
# Rule: VERY_LOW_stars -> VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.6616541353383458
# Confidence: 0.7096774193548387
# Lift: 1.01491501907735
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters -> VERY_LOW_stars
# Support: 0.6616541353383458
# Confidence: 0.9777777777777777
# Lift: 1.0487455197132616
#
# Rule: VERY_LOW_forks, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.6616541353383458
# Confidence: 0.7154471544715447
# Lift: 1.012281612177824
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.6616541353383458
# Confidence: 0.9887640449438202
# Lift: 1.0436953807740326
#
# Rule: VERY_LOW_forks -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.6616541353383458
# Confidence: 0.6984126984126984
# Lift: 1.0436953807740323
#
# Rule: VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_stars
# Support: 0.6616541353383458
# Confidence: 0.9361702127659575
# Lift: 1.012281612177824
#
# Rule: VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commiters
# Support: 0.6616541353383458
# Confidence: 0.7096774193548387
# Lift: 1.0487455197132618
#
# Rule: VERY_LOW_forks, VERY_LOW_commits -> VERY_LOW_stars
# Support: 0.8646616541353384
# Confidence: 0.9745762711864407
# Lift: 1.0453116457080374
#
# Rule: VERY_LOW_forks, VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.8646616541353384
# Confidence: 0.9349593495934959
# Lift: 1.0028193023865724
#
# Rule: VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.8646616541353384
# Confidence: 0.9913793103448276
# Lift: 1.046455938697318
#
# Rule: VERY_LOW_forks -> VERY_LOW_commits, VERY_LOW_stars
# Support: 0.8646616541353384
# Confidence: 0.9126984126984128
# Lift: 1.0464559386973182
#
# Rule: VERY_LOW_commits -> VERY_LOW_forks, VERY_LOW_stars
# Support: 0.8646616541353384
# Confidence: 0.9274193548387097
# Lift: 1.0028193023865724
#
# Rule: VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits
# Support: 0.8646616541353384
# Confidence: 0.9274193548387097
# Lift: 1.0453116457080374
#
# Rule: VERY_LOW_forks, VERY_LOW_commits, MEDIUM_RATE -> VERY_LOW_commiters
# Support: 0.37593984962406013
# Confidence: 0.7692307692307693
# Lift: 1.088379705400982
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters, MEDIUM_RATE -> VERY_LOW_commits
# Support: 0.37593984962406013
# Confidence: 0.9803921568627451
# Lift: 1.051549652118912
#
# Rule: MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_commiters -> VERY_LOW_forks
# Support: 0.37593984962406013
# Confidence: 0.9615384615384616
# Lift: 1.0149572649572651
#
# Rule: VERY_LOW_forks, VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_commiters
# Support: 0.37593984962406013
# Confidence: 0.423728813559322
# Lift: 1.0633194755356572
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.37593984962406013
# Confidence: 0.5555555555555556
# Lift: 1.07085346215781
#
# Rule: VERY_LOW_forks, MEDIUM_RATE -> VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.37593984962406013
# Confidence: 0.7142857142857143
# Lift: 1.021505376344086
#
# Rule: VERY_LOW_commits, VERY_LOW_commiters -> VERY_LOW_forks, MEDIUM_RATE
# Support: 0.37593984962406013
# Confidence: 0.5376344086021505
# Lift: 1.021505376344086
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_forks, VERY_LOW_commiters
# Support: 0.37593984962406013
# Confidence: 0.7246376811594202
# Lift: 1.0708534621578099
#
# Rule: MEDIUM_RATE, VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_commits
# Support: 0.37593984962406013
# Confidence: 0.9433962264150944
# Lift: 1.0633194755356572
#
# Rule: VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.37593984962406013
# Confidence: 0.3968253968253968
# Lift: 1.014957264957265
#
# Rule: VERY_LOW_commits -> VERY_LOW_forks, VERY_LOW_commiters, MEDIUM_RATE
# Support: 0.37593984962406013
# Confidence: 0.4032258064516129
# Lift: 1.051549652118912
#
# Rule: VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_commits, MEDIUM_RATE
# Support: 0.37593984962406013
# Confidence: 0.5319148936170213
# Lift: 1.088379705400982
#
# Rule: MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_commiters -> VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.9615384615384616
# Lift: 1.0313275434243176
#
# Rule: MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.37593984962406013
# Confidence: 0.7692307692307693
# Lift: 1.088379705400982
#
# Rule: MEDIUM_RATE, VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.37593984962406013
# Confidence: 0.9803921568627451
# Lift: 1.051549652118912
#
# Rule: VERY_LOW_commits, VERY_LOW_commiters, VERY_LOW_stars -> MEDIUM_RATE
# Support: 0.37593984962406013
# Confidence: 0.5681818181818182
# Lift: 1.0075757575757576
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.7246376811594202
# Lift: 1.0828855235303694
#
# Rule: MEDIUM_RATE, VERY_LOW_commiters -> VERY_LOW_commits, VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.9433962264150944
# Lift: 1.0816525699414445
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.37593984962406013
# Confidence: 0.7142857142857143
# Lift: 1.021505376344086
#
# Rule: VERY_LOW_commits, VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.5376344086021505
# Lift: 1.021505376344086
#
# Rule: VERY_LOW_commits, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commiters
# Support: 0.37593984962406013
# Confidence: 0.43103448275862066
# Lift: 1.0816525699414443
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.37593984962406013
# Confidence: 0.5617977528089887
# Lift: 1.0828855235303694
#
# Rule: MEDIUM_RATE -> VERY_LOW_commits, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.6666666666666666
# Lift: 1.0075757575757576
#
# Rule: VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.4032258064516129
# Lift: 1.051549652118912
#
# Rule: VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.5319148936170213
# Lift: 1.088379705400982
#
# Rule: VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.37593984962406013
# Confidence: 0.4032258064516129
# Lift: 1.0313275434243176
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters, MEDIUM_RATE -> VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.9803921568627451
# Lift: 1.051549652118912
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters, VERY_LOW_stars -> MEDIUM_RATE
# Support: 0.37593984962406013
# Confidence: 0.5681818181818182
# Lift: 1.0075757575757576
#
# Rule: VERY_LOW_forks, MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.37593984962406013
# Confidence: 0.7246376811594202
# Lift: 1.0252852297255626
#
# Rule: MEDIUM_RATE, VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.37593984962406013
# Confidence: 0.9803921568627451
# Lift: 1.0348583877995643
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.5555555555555556
# Lift: 1.0555555555555556
#
# Rule: VERY_LOW_forks, MEDIUM_RATE -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.7142857142857143
# Lift: 1.0674157303370786
#
# Rule: VERY_LOW_forks, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commiters
# Support: 0.37593984962406013
# Confidence: 0.4065040650406504
# Lift: 1.0200951066114434
#
# Rule: MEDIUM_RATE, VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.9433962264150944
# Lift: 1.0200951066114434
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks, MEDIUM_RATE
# Support: 0.37593984962406013
# Confidence: 0.5617977528089887
# Lift: 1.0674157303370786
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commiters
# Support: 0.37593984962406013
# Confidence: 0.7142857142857143
# Lift: 1.0555555555555556
#
# Rule: VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.3968253968253968
# Lift: 1.0348583877995643
#
# Rule: VERY_LOW_commiters -> VERY_LOW_forks, MEDIUM_RATE, VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.5319148936170213
# Lift: 1.0252852297255626
#
# Rule: MEDIUM_RATE -> VERY_LOW_forks, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.37593984962406013
# Confidence: 0.6666666666666666
# Lift: 1.0075757575757576
#
# Rule: VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commiters, MEDIUM_RATE
# Support: 0.37593984962406013
# Confidence: 0.4032258064516129
# Lift: 1.051549652118912
#
# Rule: VERY_LOW_forks, VERY_LOW_commits, MEDIUM_RATE -> VERY_LOW_stars
# Support: 0.48120300751879697
# Confidence: 0.9846153846153847
# Lift: 1.0560794044665014
#
# Rule: MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.48120300751879697
# Confidence: 0.9846153846153847
# Lift: 1.0393162393162394
#
# Rule: VERY_LOW_forks, VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.48120300751879697
# Confidence: 0.5423728813559322
# Lift: 1.0305084745762711
#
# Rule: VERY_LOW_forks, MEDIUM_RATE -> VERY_LOW_commits, VERY_LOW_stars
# Support: 0.48120300751879697
# Confidence: 0.9142857142857143
# Lift: 1.0482758620689656
#
# Rule: VERY_LOW_forks, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.48120300751879697
# Confidence: 0.5203252032520325
# Lift: 1.0029456816307292
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_forks, VERY_LOW_stars
# Support: 0.48120300751879697
# Confidence: 0.9275362318840579
# Lift: 1.0029456816307292
#
# Rule: VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_forks, MEDIUM_RATE
# Support: 0.48120300751879697
# Confidence: 0.5517241379310345
# Lift: 1.0482758620689656
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits
# Support: 0.48120300751879697
# Confidence: 0.9142857142857143
# Lift: 1.0305084745762711
#
# Rule: VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_stars
# Support: 0.48120300751879697
# Confidence: 0.5079365079365079
# Lift: 1.0393162393162394
#
# Rule: VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits, MEDIUM_RATE
# Support: 0.48120300751879697
# Confidence: 0.5161290322580645
# Lift: 1.0560794044665012
#
# Rule: VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_commiters -> VERY_LOW_stars
# Support: 0.6541353383458647
# Confidence: 0.9775280898876405
# Lift: 1.0484777093149693
#
# Rule: VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.6541353383458647
# Confidence: 0.7565217391304347
# Lift: 1.0703977798334876
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.6541353383458647
# Confidence: 0.9886363636363638
# Lift: 1.060392228739003
#
# Rule: VERY_LOW_commits, VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.6541353383458647
# Confidence: 0.9886363636363638
# Lift: 1.0435606060606062
#
# Rule: VERY_LOW_forks, VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.6541353383458647
# Confidence: 0.7372881355932204
# Lift: 1.1017901352123405
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters -> VERY_LOW_commits, VERY_LOW_stars
# Support: 0.6541353383458647
# Confidence: 0.9666666666666668
# Lift: 1.1083333333333336
#
# Rule: VERY_LOW_forks, VERY_LOW_stars -> VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.6541353383458647
# Confidence: 0.7073170731707317
# Lift: 1.011539470233412
#
# Rule: VERY_LOW_commits, VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_stars
# Support: 0.6541353383458647
# Confidence: 0.935483870967742
# Lift: 1.0115394702334122
#
# Rule: VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commiters
# Support: 0.6541353383458647
# Confidence: 0.7500000000000001
# Lift: 1.1083333333333336
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits
# Support: 0.6541353383458647
# Confidence: 0.9775280898876405
# Lift: 1.1017901352123407
#
# Rule: VERY_LOW_forks -> VERY_LOW_commits, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.6541353383458647
# Confidence: 0.6904761904761906
# Lift: 1.0435606060606062
#
# Rule: VERY_LOW_commits -> VERY_LOW_forks, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.6541353383458647
# Confidence: 0.7016129032258065
# Lift: 1.060392228739003
#
# Rule: VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_stars
# Support: 0.6541353383458647
# Confidence: 0.9255319148936171
# Lift: 1.0703977798334876
#
# Rule: VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.6541353383458647
# Confidence: 0.7016129032258065
# Lift: 1.0484777093149693
#
# Rule: VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_commiters, MEDIUM_RATE -> VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.98
# Lift: 1.0511290322580646
#
# Rule: VERY_LOW_forks, VERY_LOW_commits, MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.3684210526315789
# Confidence: 0.765625
# Lift: 1.083277925531915
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters, MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.3684210526315789
# Confidence: 0.98
# Lift: 1.0511290322580646
#
# Rule: MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.3684210526315789
# Confidence: 0.98
# Lift: 1.0344444444444445
#
# Rule: VERY_LOW_forks, VERY_LOW_commits, MEDIUM_RATE -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.7538461538461538
# Lift: 1.1265341400172861
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters, MEDIUM_RATE -> VERY_LOW_commits, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.9607843137254902
# Lift: 1.1015889114266397
#
# Rule: VERY_LOW_forks, MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.3684210526315789
# Confidence: 0.7101449275362318
# Lift: 1.015583606046439
#
# Rule: VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.5505617977528089
# Lift: 1.046067415730337
#
# Rule: VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commiters
# Support: 0.3684210526315789
# Confidence: 0.4260869565217391
# Lift: 1.069237079573421
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.3684210526315789
# Confidence: 0.5568181818181818
# Lift: 1.0732872200263504
#
# Rule: MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.9423076923076923
# Lift: 1.0189180737961225
#
# Rule: MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commiters
# Support: 0.3684210526315789
# Confidence: 0.7538461538461538
# Lift: 1.1140170940170941
#
# Rule: MEDIUM_RATE, VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits
# Support: 0.3684210526315789
# Confidence: 0.9607843137254902
# Lift: 1.0829179129278832
#
# Rule: VERY_LOW_commits, VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks, MEDIUM_RATE
# Support: 0.3684210526315789
# Confidence: 0.5568181818181818
# Lift: 1.0579545454545454
#
# Rule: VERY_LOW_forks, MEDIUM_RATE -> VERY_LOW_commits, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.7
# Lift: 1.0579545454545454
#
# Rule: VERY_LOW_forks, VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.4152542372881356
# Lift: 1.0829179129278832
#
# Rule: VERY_LOW_forks, VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.5444444444444444
# Lift: 1.114017094017094
#
# Rule: VERY_LOW_forks, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.3684210526315789
# Confidence: 0.3983739837398374
# Lift: 1.0189180737961225
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_forks, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.7101449275362318
# Lift: 1.0732872200263504
#
# Rule: MEDIUM_RATE, VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.9245283018867925
# Lift: 1.069237079573421
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.3684210526315789
# Confidence: 0.7
# Lift: 1.046067415730337
#
# Rule: VERY_LOW_commits, VERY_LOW_commiters -> VERY_LOW_forks, MEDIUM_RATE, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.5268817204301075
# Lift: 1.0155836060464392
#
# Rule: VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commiters, MEDIUM_RATE
# Support: 0.3684210526315789
# Confidence: 0.4224137931034483
# Lift: 1.1015889114266397
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits, MEDIUM_RATE
# Support: 0.3684210526315789
# Confidence: 0.5505617977528089
# Lift: 1.126534140017286
#
# Rule: VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.3888888888888889
# Lift: 1.0344444444444445
#
# Rule: VERY_LOW_commits -> VERY_LOW_forks, VERY_LOW_commiters, MEDIUM_RATE, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.3951612903225806
# Lift: 1.0511290322580644
#
# Rule: VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_commits, MEDIUM_RATE, VERY_LOW_stars
# Support: 0.3684210526315789
# Confidence: 0.5212765957446809
# Lift: 1.083277925531915
#
# Rule: VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_commiters, MEDIUM_RATE
# Support: 0.3684210526315789
# Confidence: 0.3951612903225806
# Lift: 1.0511290322580644
