# %%
from datetime import datetime
from git import Repo, Git
import subprocess
import os
import csv

filename = "C:\\Users\leu_m\PycharmProjects\master-terraform-sec-adoption\\aws\csv\\aws-analysis-tfsec.csv"

METRICS_FILE = "C:\\Users\leu_m\PycharmProjects\master-terraform-sec-adoption\\aws\csv\dataset_repo_metadata.csv"
STAR_FILTERED_REPOS = "C:\\Users\leu_m\PycharmProjects\master-terraform-sec-adoption\\aws\csv\dataset.csv"
INPUT_FILE = "C:\\Users\leu_m\PycharmProjects\master-terraform-sec-adoption\\aws\csv\\results-tfsec.csv"
PATH_OF_TMP_DIRECTORY = "C:\\Users\leu_m\PycharmProjects\master-terraform-sec-adoption\\tmp\\repos"

stars_by_projects = {}
forks_by_projects = {}
contrib_by_projects = {}

with open(STAR_FILTERED_REPOS, 'r') as f:
    tmp_repo_names = f.readlines()
repo_names = [k.strip("\n") for k in tmp_repo_names]

with open(METRICS_FILE, 'r') as f:
    #f.readline()
    rows = f.readlines()
    for item in rows:
        column = item.split(',')
        if column[0] in repo_names:
            stars_by_projects[column[0]] = int(column[1])
            forks_by_projects[column[0]] = int(column[2])
            contrib_by_projects[column[0]] = int(column[3].strip("\n"))

with open(INPUT_FILE, 'r') as f:
    f.readline()
    repo_results = f.readlines()

repo_stars_mine = {}
with open(METRICS_FILE, 'r') as f:
    f.readline()
    rows = f.readlines()
    for item in rows:
        column = item.split(',')
        if column[0] in repo_names:
            repo_stars_mine[column[0]] = column[1]

stars_passed_rate_mine = {}
for row in repo_results:
    columns = row.split(',')
    repo_name = columns[0]
    if repo_name in repo_stars_mine:
        passed_count = len(columns[3].split(';'))
        failed_count = len(columns[4].split(';'))
        if passed_count + failed_count > 0:
            stars_passed_rate_mine[repo_name] = passed_count/(passed_count+failed_count) 

def get_commit_count_until_hash(repo_name):
    try:
        # Create the directory if it doesn't exist
        if not os.path.exists(PATH_OF_TMP_DIRECTORY):
            os.makedirs(PATH_OF_TMP_DIRECTORY)
        
        # Change directory to the specified directory
        os.chdir(PATH_OF_TMP_DIRECTORY)
        
        # Clone the repository
        repo_url = "https://github.com/"+repo_name
        subprocess.run(["git", "clone", repo_url])
        repo_name = str(repo_name.split("/")[1]).replace(".git","")
        
        # Change directory to the cloned repository
        os.chdir(os.path.join(PATH_OF_TMP_DIRECTORY, repo_name))
        
        commit_hash = get_closest_commit(os.path.join(PATH_OF_TMP_DIRECTORY, repo_name), datetime(2022, 10, 13))
        
        # Fetch all commits and count them
        output = subprocess.check_output(["git", "rev-list", "--count", commit_hash]).decode("utf-8").strip()
        commit_count = int(output)
        
        output = subprocess.check_output(["git", "log", "--format=%aN", commit_hash]).decode("utf-8")
        contributors = len(set(output.splitlines()))
        
        return commit_count, contributors
    
    except subprocess.CalledProcessError as e:
        print("Error:", e)
        return None

def get_closest_commit(repo_path, target_date):
    git = Git(repo_path)

    # Use rev-list to find the closest commit to the target date
    closest_commit_hash = git.rev_list('-n', '1', '--before={:%Y-%m-%d %H:%M:%S}'.format(target_date), '--all')

    return closest_commit_hash

with open(filename, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(["project_name", "stars_passed", "stars", "forks", "contributors", "commits", "commiters"])
        for row in stars_passed_rate_mine.keys():
            try:
                report = get_commit_count_until_hash(row)
                commit_count = report[0]
                contributors = report[1]
                
                if commit_count is None:
                    commit_count = 0
                    
                if contributors is None:
                    contributors = 0
                    
                csv_writer.writerow([row, stars_passed_rate_mine.get(row), stars_by_projects.get(row), 
                                    forks_by_projects.get(row), contrib_by_projects.get(row), commit_count, contributors])
            except Exception as e:
                print(row)
# Out:
# riferrei/pacman-with-elasticsearch
# Error: Command '['git', 'rev-list', '--count', '']' returned non-zero exit status 128.
# uktrade/data-workspace
# Cecure-Intelligence-Limited/cil-internship-cohort-04
# xaynetwork/xayn_infrastructure

# %%
import csv
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd

filename = "C:\\Users\leu_m\PycharmProjects\master-terraform-sec-adoption\\aws\csv\\aws-analysis-tfsec.csv"

# Sample DataFrame
data = pd.read_csv(filename)

# Create DataFrame
df = pd.DataFrame(data)

# Function to map passed rate to categories
def map_passed_rate(passed_rate):
    if passed_rate < 0.3:
        return "LOW_RATE"
    #elif passed_rate < 0.4:
    #    return "LOW_RATE"
    elif passed_rate < 0.6:
        return "MEDIUM_RATE"
    #elif passed_rate < 0.8:
     #   return "HIGH_RATE"
    else:
        return "HIGH_RATE"

    # Function to map other continuous variables to categories based on min-max normalization
def map_to_categories(value, min_val, max_val, category):
    if value < min_val + 0.1 * (max_val - min_val):
        return "VERY_LOW_"+category
    elif value < min_val + 0.2 * (max_val - min_val):
        return "LOW_"+category
    elif value < min_val + 0.3 * (max_val - min_val):
        return "MODERATE_"+category
    elif value < min_val + 0.4 * (max_val - min_val):
        return "BELOW_AVERAGE_"+category
    elif value < min_val + 0.5 * (max_val - min_val):
        return "AVERAGE_"+category
    elif value < min_val + 0.6 * (max_val - min_val):
        return "ABOVE_AVERAGE_"+category
    elif value < min_val + 0.7 * (max_val - min_val):
        return "HIGH_"+category
    elif value < min_val + 0.8 * (max_val - min_val):
        return "VERY_HIGH_"+category
    elif value < min_val + 0.9 * (max_val - min_val):
        return "EXTREMELY_HIGH_"+category
    else:
        return "EXCEPTIONALLY_HIGH_"+category

# Transforming passed rate
df['passed_rate_category'] = df['stars_passed'].apply(map_passed_rate)

# Transforming stars, forks, and contributors
for col in ['stars', 'forks', 'commits', 'commiters']:
    min_val = df[col].min()
    max_val = df[col].max()
    df[col + '_category'] = df[col].apply(lambda x: map_to_categories(x, min_val, max_val, col))

# Print the transformed DataFrame
#print(df.columns)

print(df[['passed_rate_category', 'stars_category', 'forks_category', 'commits_category', 'commiters_category']])

aux = df[['passed_rate_category', 'stars_category', 'forks_category', 'commits_category', 'commiters_category']]

transactions = aux.values

print(transactions)

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_selected = pd.DataFrame(te_ary, columns=te.columns_)

# Generate frequent itemsets with minimum support of 0.3
frequent_itemsets = apriori(df_selected, min_support=0.3, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Print the rules
for index, rule in rules.iterrows():
    antecedents = ', '.join(rule['antecedents'])
    consequents = ', '.join(rule['consequents'])
    print(f"Rule: {antecedents} -> {consequents}")
    print(f"Support: {rule['support']}")
    print(f"Confidence: {rule['confidence']}")
    print(f"Lift: {rule['lift']}")
    print()
    
filename = "C:\\Users\leu_m\PycharmProjects\master-terraform-sec-adoption\\rq3\\report-aws-tfsec.csv"
with open(filename, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(["antecedents", "consequents", "Support", "Confidence", "Lift"])
        for index, rule in rules.iterrows():
            antecedents = ', '.join(rule['antecedents'])
            consequents = ', '.join(rule['consequents'])
            csv_writer.writerow([antecedents, consequents, rule['support'], rule['confidence'], rule['lift']])
# Out:
#     passed_rate_category            stars_category            forks_category  \
# 0            MEDIUM_RATE  EXCEPTIONALLY_HIGH_stars             AVERAGE_forks
# 1               LOW_RATE      EXTREMELY_HIGH_stars                 LOW_forks
# 2            MEDIUM_RATE           VERY_HIGH_stars                 LOW_forks
# 3              HIGH_RATE             AVERAGE_stars  EXCEPTIONALLY_HIGH_forks
# 4               LOW_RATE            MODERATE_stars                 LOW_forks
# ..                   ...                       ...                       ...
# 378          MEDIUM_RATE            VERY_LOW_stars            VERY_LOW_forks
# 379            HIGH_RATE            VERY_LOW_stars            VERY_LOW_forks
# 380          MEDIUM_RATE            VERY_LOW_stars            VERY_LOW_forks
# 381          MEDIUM_RATE            VERY_LOW_stars            VERY_LOW_forks
# 382          MEDIUM_RATE            VERY_LOW_stars            VERY_LOW_forks
#
#      commits_category        commiters_category
# 0    MODERATE_commits        MODERATE_commiters
# 1    VERY_LOW_commits             LOW_commiters
# 2         LOW_commits        MODERATE_commiters
# 3        HIGH_commits  EXTREMELY_HIGH_commiters
# 4         LOW_commits             LOW_commiters
# ..                ...                       ...
# 378  VERY_LOW_commits        VERY_LOW_commiters
# 379  VERY_LOW_commits        VERY_LOW_commiters
# 380  VERY_LOW_commits        VERY_LOW_commiters
# 381  VERY_LOW_commits        VERY_LOW_commiters
# 382  VERY_LOW_commits        VERY_LOW_commiters
#
# [383 rows x 5 columns]
# [['MEDIUM_RATE' 'EXCEPTIONALLY_HIGH_stars' 'AVERAGE_forks'
#   'MODERATE_commits' 'MODERATE_commiters']
#  ['LOW_RATE' 'EXTREMELY_HIGH_stars' 'LOW_forks' 'VERY_LOW_commits'
#   'LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_HIGH_stars' 'LOW_forks' 'LOW_commits'
#   'MODERATE_commiters']
#  ...
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']
#  ['MEDIUM_RATE' 'VERY_LOW_stars' 'VERY_LOW_forks' 'VERY_LOW_commits'
#   'VERY_LOW_commiters']]
# Rule: VERY_LOW_commiters -> VERY_LOW_commits
# Support: 0.9033942558746736
# Confidence: 0.9719101123595505
# Lift: 1.0575044688457609
#
# Rule: VERY_LOW_commits -> VERY_LOW_commiters
# Support: 0.9033942558746736
# Confidence: 0.9829545454545454
# Lift: 1.0575044688457609
#
# Rule: VERY_LOW_commiters -> VERY_LOW_forks
# Support: 0.9112271540469974
# Confidence: 0.9803370786516854
# Lift: 1.020296470444553
#
# Rule: VERY_LOW_forks -> VERY_LOW_commiters
# Support: 0.9112271540469974
# Confidence: 0.9483695652173912
# Lift: 1.020296470444553
#
# Rule: VERY_LOW_commiters -> VERY_LOW_stars
# Support: 0.9190600522193212
# Confidence: 0.9887640449438203
# Lift: 1.0262781279498188
#
# Rule: VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.9190600522193212
# Confidence: 0.9539295392953929
# Lift: 1.0262781279498188
#
# Rule: VERY_LOW_forks -> VERY_LOW_commits
# Support: 0.8955613577023499
# Confidence: 0.9320652173913043
# Lift: 1.0141505064229248
#
# Rule: VERY_LOW_commits -> VERY_LOW_forks
# Support: 0.8955613577023499
# Confidence: 0.9744318181818181
# Lift: 1.0141505064229248
#
# Rule: VERY_LOW_commits -> VERY_LOW_stars
# Support: 0.9033942558746736
# Confidence: 0.9829545454545454
# Lift: 1.0202482138457747
#
# Rule: VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.9033942558746736
# Confidence: 0.9376693766937668
# Lift: 1.0202482138457747
#
# Rule: VERY_LOW_forks -> VERY_LOW_stars
# Support: 0.9503916449086162
# Confidence: 0.9891304347826086
# Lift: 1.0266584187581005
#
# Rule: VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.9503916449086162
# Confidence: 0.9864498644986449
# Lift: 1.0266584187581005
#
# Rule: VERY_LOW_commiters, MEDIUM_RATE -> VERY_LOW_commits
# Support: 0.4046997389033943
# Confidence: 0.9627329192546584
# Lift: 1.0475190570299266
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_commiters
# Support: 0.4046997389033943
# Confidence: 0.9748427672955975
# Lift: 1.0487774715567804
#
# Rule: VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.4046997389033943
# Confidence: 0.4353932584269663
# Lift: 1.0487774715567804
#
# Rule: VERY_LOW_commits -> VERY_LOW_commiters, MEDIUM_RATE
# Support: 0.4046997389033943
# Confidence: 0.4403409090909091
# Lift: 1.0475190570299266
#
# Rule: VERY_LOW_commiters, MEDIUM_RATE -> VERY_LOW_forks
# Support: 0.40992167101827676
# Confidence: 0.9751552795031055
# Lift: 1.0149034566567647
#
# Rule: VERY_LOW_forks -> VERY_LOW_commiters, MEDIUM_RATE
# Support: 0.40992167101827676
# Confidence: 0.4266304347826087
# Lift: 1.0149034566567647
#
# Rule: VERY_LOW_commiters, MEDIUM_RATE -> VERY_LOW_stars
# Support: 0.40992167101827676
# Confidence: 0.9751552795031055
# Lift: 1.012153040785066
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.40992167101827676
# Confidence: 0.9401197604790419
# Lift: 1.0114209782681827
#
# Rule: VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.40992167101827676
# Confidence: 0.4410112359550562
# Lift: 1.0114209782681827
#
# Rule: VERY_LOW_stars -> VERY_LOW_commiters, MEDIUM_RATE
# Support: 0.40992167101827676
# Confidence: 0.4254742547425474
# Lift: 1.0121530407850663
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_forks
# Support: 0.4046997389033943
# Confidence: 0.9748427672955975
# Lift: 1.0145782061799289
#
# Rule: VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.4046997389033943
# Confidence: 0.4211956521739131
# Lift: 1.0145782061799289
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_stars
# Support: 0.4046997389033943
# Confidence: 0.9748427672955975
# Lift: 1.011828671745837
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.4046997389033943
# Confidence: 0.9281437125748503
# Lift: 1.0098836418072945
#
# Rule: VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.4046997389033943
# Confidence: 0.4403409090909091
# Lift: 1.0098836418072945
#
# Rule: VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.4046997389033943
# Confidence: 0.42005420054200543
# Lift: 1.011828671745837
#
# Rule: MEDIUM_RATE, VERY_LOW_forks -> VERY_LOW_stars
# Support: 0.43342036553524804
# Confidence: 0.9822485207100592
# Lift: 1.0195154022546142
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.43342036553524804
# Confidence: 0.9940119760479041
# Lift: 1.0345287685498568
#
# Rule: VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.43342036553524804
# Confidence: 0.45108695652173914
# Lift: 1.0345287685498568
#
# Rule: VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_forks
# Support: 0.43342036553524804
# Confidence: 0.44986449864498645
# Lift: 1.0195154022546142
#
# Rule: VERY_LOW_commiters, VERY_LOW_forks -> VERY_LOW_commits
# Support: 0.8851174934725848
# Confidence: 0.9713467048710601
# Lift: 1.0568914430841363
#
# Rule: VERY_LOW_commiters, VERY_LOW_commits -> VERY_LOW_forks
# Support: 0.8851174934725848
# Confidence: 0.9797687861271677
# Lift: 1.0197050138225685
#
# Rule: VERY_LOW_forks, VERY_LOW_commits -> VERY_LOW_commiters
# Support: 0.8851174934725848
# Confidence: 0.988338192419825
# Lift: 1.063296426114587
#
# Rule: VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_commits
# Support: 0.8851174934725848
# Confidence: 0.952247191011236
# Lift: 1.0632964261145872
#
# Rule: VERY_LOW_forks -> VERY_LOW_commiters, VERY_LOW_commits
# Support: 0.8851174934725848
# Confidence: 0.921195652173913
# Lift: 1.0197050138225685
#
# Rule: VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_forks
# Support: 0.8851174934725848
# Confidence: 0.9630681818181818
# Lift: 1.0568914430841365
#
# Rule: VERY_LOW_commiters, VERY_LOW_commits -> VERY_LOW_stars
# Support: 0.8929503916449086
# Confidence: 0.9884393063583816
# Lift: 1.0259410686592416
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.8929503916449086
# Confidence: 0.9715909090909091
# Lift: 1.0571571539256197
#
# Rule: VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.8929503916449086
# Confidence: 0.9884393063583816
# Lift: 1.0634052088069106
#
# Rule: VERY_LOW_commiters -> VERY_LOW_commits, VERY_LOW_stars
# Support: 0.8929503916449086
# Confidence: 0.9606741573033708
# Lift: 1.0634052088069106
#
# Rule: VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.8929503916449086
# Confidence: 0.9715909090909091
# Lift: 1.0571571539256197
#
# Rule: VERY_LOW_stars -> VERY_LOW_commiters, VERY_LOW_commits
# Support: 0.8929503916449086
# Confidence: 0.9268292682926829
# Lift: 1.0259410686592414
#
# Rule: VERY_LOW_commiters, VERY_LOW_forks -> VERY_LOW_stars
# Support: 0.9086161879895561
# Confidence: 0.997134670487106
# Lift: 1.034966338202064
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.9086161879895561
# Confidence: 0.9886363636363635
# Lift: 1.028934041501976
#
# Rule: VERY_LOW_forks, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.9086161879895561
# Confidence: 0.9560439560439561
# Lift: 1.028552907766391
#
# Rule: VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_stars
# Support: 0.9086161879895561
# Confidence: 0.9775280898876405
# Lift: 1.028552907766391
#
# Rule: VERY_LOW_forks -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.9086161879895561
# Confidence: 0.9456521739130435
# Lift: 1.0289340415019763
#
# Rule: VERY_LOW_stars -> VERY_LOW_commiters, VERY_LOW_forks
# Support: 0.9086161879895561
# Confidence: 0.9430894308943089
# Lift: 1.034966338202064
#
# Rule: VERY_LOW_forks, VERY_LOW_commits -> VERY_LOW_stars
# Support: 0.8929503916449086
# Confidence: 0.9970845481049563
# Lift: 1.0349143141577188
#
# Rule: VERY_LOW_forks, VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.8929503916449086
# Confidence: 0.9395604395604396
# Lift: 1.0223058191808192
#
# Rule: VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.8929503916449086
# Confidence: 0.9884393063583816
# Lift: 1.0287289519979896
#
# Rule: VERY_LOW_forks -> VERY_LOW_commits, VERY_LOW_stars
# Support: 0.8929503916449086
# Confidence: 0.9293478260869565
# Lift: 1.0287289519979894
#
# Rule: VERY_LOW_commits -> VERY_LOW_forks, VERY_LOW_stars
# Support: 0.8929503916449086
# Confidence: 0.9715909090909091
# Lift: 1.0223058191808192
#
# Rule: VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits
# Support: 0.8929503916449086
# Confidence: 0.9268292682926829
# Lift: 1.0349143141577186
#
# Rule: VERY_LOW_commiters, VERY_LOW_forks, MEDIUM_RATE -> VERY_LOW_commits
# Support: 0.39425587467362927
# Confidence: 0.961783439490446
# Lift: 1.0464859583092068
#
# Rule: VERY_LOW_commiters, VERY_LOW_commits, MEDIUM_RATE -> VERY_LOW_forks
# Support: 0.39425587467362927
# Confidence: 0.9741935483870968
# Lift: 1.0139025245441795
#
# Rule: MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commits -> VERY_LOW_commiters
# Support: 0.39425587467362927
# Confidence: 0.9741935483870968
# Lift: 1.0480790141355565
#
# Rule: VERY_LOW_commiters, VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.39425587467362927
# Confidence: 0.4326647564469914
# Lift: 1.0422050422591052
#
# Rule: VERY_LOW_commiters, MEDIUM_RATE -> VERY_LOW_forks, VERY_LOW_commits
# Support: 0.39425587467362927
# Confidence: 0.9378881987577641
# Lift: 1.0472629158140632
#
# Rule: VERY_LOW_forks, VERY_LOW_commits -> VERY_LOW_commiters, MEDIUM_RATE
# Support: 0.39425587467362927
# Confidence: 0.44023323615160354
# Lift: 1.0472629158140632
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_forks
# Support: 0.39425587467362927
# Confidence: 0.949685534591195
# Lift: 1.0422050422591052
#
# Rule: VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commits
# Support: 0.39425587467362927
# Confidence: 0.42415730337078655
# Lift: 1.0480790141355565
#
# Rule: VERY_LOW_forks -> VERY_LOW_commiters, VERY_LOW_commits, MEDIUM_RATE
# Support: 0.39425587467362927
# Confidence: 0.41032608695652173
# Lift: 1.0139025245441795
#
# Rule: VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_forks, MEDIUM_RATE
# Support: 0.39425587467362927
# Confidence: 0.42897727272727276
# Lift: 1.0464859583092068
#
# Rule: VERY_LOW_commiters, VERY_LOW_commits, MEDIUM_RATE -> VERY_LOW_stars
# Support: 0.39425587467362927
# Confidence: 0.9741935483870968
# Lift: 1.0111548212256316
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars, MEDIUM_RATE -> VERY_LOW_commits
# Support: 0.39425587467362927
# Confidence: 0.961783439490446
# Lift: 1.0464859583092068
#
# Rule: MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.39425587467362927
# Confidence: 0.9741935483870968
# Lift: 1.0480790141355565
#
# Rule: VERY_LOW_commiters, VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.39425587467362927
# Confidence: 0.4364161849710983
# Lift: 1.0008826278079679
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.39425587467362927
# Confidence: 0.42897727272727276
# Lift: 1.0333226129216695
#
# Rule: VERY_LOW_commiters, MEDIUM_RATE -> VERY_LOW_commits, VERY_LOW_stars
# Support: 0.39425587467362927
# Confidence: 0.9378881987577641
# Lift: 1.0381826015150972
#
# Rule: VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_commiters, MEDIUM_RATE
# Support: 0.39425587467362927
# Confidence: 0.4364161849710983
# Lift: 1.0381826015150972
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.39425587467362927
# Confidence: 0.949685534591195
# Lift: 1.0333226129216695
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_commiters, VERY_LOW_commits
# Support: 0.39425587467362927
# Confidence: 0.9041916167664671
# Lift: 1.0008826278079679
#
# Rule: VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_stars
# Support: 0.39425587467362927
# Confidence: 0.42415730337078655
# Lift: 1.0480790141355565
#
# Rule: VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_stars, MEDIUM_RATE
# Support: 0.39425587467362927
# Confidence: 0.42897727272727276
# Lift: 1.0464859583092068
#
# Rule: VERY_LOW_stars -> VERY_LOW_commiters, VERY_LOW_commits, MEDIUM_RATE
# Support: 0.39425587467362927
# Confidence: 0.4092140921409214
# Lift: 1.0111548212256316
#
# Rule: VERY_LOW_commiters, VERY_LOW_forks, MEDIUM_RATE -> VERY_LOW_stars
# Support: 0.4073107049608355
# Confidence: 0.9936305732484076
# Lift: 1.0313292941846615
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars, MEDIUM_RATE -> VERY_LOW_forks
# Support: 0.4073107049608355
# Confidence: 0.9936305732484076
# Lift: 1.0341318194405982
#
# Rule: MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.4073107049608355
# Confidence: 0.9397590361445782
# Lift: 1.0110328956274535
#
# Rule: VERY_LOW_commiters, VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.4073107049608355
# Confidence: 0.4469914040114613
# Lift: 1.0251359744693993
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_forks
# Support: 0.4073107049608355
# Confidence: 0.4431818181818181
# Lift: 1.0043706293706294
#
# Rule: VERY_LOW_commiters, MEDIUM_RATE -> VERY_LOW_forks, VERY_LOW_stars
# Support: 0.4073107049608355
# Confidence: 0.9689440993788819
# Lift: 1.0195208518189884
#
# Rule: VERY_LOW_forks, VERY_LOW_stars -> VERY_LOW_commiters, MEDIUM_RATE
# Support: 0.4073107049608355
# Confidence: 0.42857142857142855
# Lift: 1.0195208518189884
#
# Rule: MEDIUM_RATE, VERY_LOW_forks -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.4073107049608355
# Confidence: 0.923076923076923
# Lift: 1.0043706293706292
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_commiters, VERY_LOW_forks
# Support: 0.4073107049608355
# Confidence: 0.934131736526946
# Lift: 1.0251359744693993
#
# Rule: VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_stars
# Support: 0.4073107049608355
# Confidence: 0.43820224719101125
# Lift: 1.0110328956274537
#
# Rule: VERY_LOW_forks -> VERY_LOW_commiters, VERY_LOW_stars, MEDIUM_RATE
# Support: 0.4073107049608355
# Confidence: 0.42391304347826086
# Lift: 1.0341318194405982
#
# Rule: VERY_LOW_stars -> VERY_LOW_commiters, VERY_LOW_forks, MEDIUM_RATE
# Support: 0.4073107049608355
# Confidence: 0.4227642276422764
# Lift: 1.0313292941846615
#
# Rule: MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commits -> VERY_LOW_stars
# Support: 0.402088772845953
# Confidence: 0.9935483870967742
# Lift: 1.0312439898592534
#
# Rule: MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.402088772845953
# Confidence: 0.927710843373494
# Lift: 1.0094126506024095
#
# Rule: MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.402088772845953
# Confidence: 0.9935483870967742
# Lift: 1.034046283309958
#
# Rule: MEDIUM_RATE, VERY_LOW_forks -> VERY_LOW_commits, VERY_LOW_stars
# Support: 0.402088772845953
# Confidence: 0.911242603550296
# Lift: 1.008687621849027
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_forks, VERY_LOW_stars
# Support: 0.402088772845953
# Confidence: 0.9685534591194969
# Lift: 1.0191098209966134
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits
# Support: 0.402088772845953
# Confidence: 0.9221556886227544
# Lift: 1.029695710619577
#
# Rule: VERY_LOW_forks, VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.402088772845953
# Confidence: 0.4489795918367347
# Lift: 1.0296957106195772
#
# Rule: VERY_LOW_forks, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.402088772845953
# Confidence: 0.4230769230769231
# Lift: 1.0191098209966134
#
# Rule: VERY_LOW_commits, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_forks
# Support: 0.402088772845953
# Confidence: 0.4450867052023122
# Lift: 1.008687621849027
#
# Rule: VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_stars
# Support: 0.402088772845953
# Confidence: 0.41847826086956524
# Lift: 1.034046283309958
#
# Rule: VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_stars
# Support: 0.402088772845953
# Confidence: 0.4375
# Lift: 1.0094126506024097
#
# Rule: VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commits
# Support: 0.402088772845953
# Confidence: 0.4173441734417344
# Lift: 1.0312439898592534
#
# Rule: VERY_LOW_commiters, VERY_LOW_forks, VERY_LOW_commits -> VERY_LOW_stars
# Support: 0.8825065274151436
# Confidence: 0.9970501474926253
# Lift: 1.0348786083731043
#
# Rule: VERY_LOW_commiters, VERY_LOW_forks, VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.8825065274151436
# Confidence: 0.9712643678160919
# Lift: 1.0568018547544409
#
# Rule: VERY_LOW_commiters, VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.8825065274151436
# Confidence: 0.9883040935672514
# Lift: 1.0285882278159164
#
# Rule: VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.8825065274151436
# Confidence: 0.9883040935672514
# Lift: 1.0632597411130822
#
# Rule: VERY_LOW_commiters, VERY_LOW_forks -> VERY_LOW_commits, VERY_LOW_stars
# Support: 0.8825065274151436
# Confidence: 0.9684813753581661
# Lift: 1.0720473027808604
#
# Rule: VERY_LOW_commiters, VERY_LOW_commits -> VERY_LOW_forks, VERY_LOW_stars
# Support: 0.8825065274151436
# Confidence: 0.976878612716763
# Lift: 1.027869529314616
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits
# Support: 0.8825065274151436
# Confidence: 0.9602272727272726
# Lift: 1.0722071296050886
#
# Rule: VERY_LOW_forks, VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.8825065274151436
# Confidence: 0.9854227405247813
# Lift: 1.0722071296050888
#
# Rule: VERY_LOW_forks, VERY_LOW_stars -> VERY_LOW_commiters, VERY_LOW_commits
# Support: 0.8825065274151436
# Confidence: 0.9285714285714286
# Lift: 1.027869529314616
#
# Rule: VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_commiters, VERY_LOW_forks
# Support: 0.8825065274151436
# Confidence: 0.976878612716763
# Lift: 1.0720473027808604
#
# Rule: VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_stars
# Support: 0.8825065274151436
# Confidence: 0.949438202247191
# Lift: 1.0632597411130822
#
# Rule: VERY_LOW_forks -> VERY_LOW_commiters, VERY_LOW_commits, VERY_LOW_stars
# Support: 0.8825065274151436
# Confidence: 0.9184782608695652
# Lift: 1.0285882278159166
#
# Rule: VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_forks, VERY_LOW_stars
# Support: 0.8825065274151436
# Confidence: 0.9602272727272726
# Lift: 1.0568018547544409
#
# Rule: VERY_LOW_stars -> VERY_LOW_commiters, VERY_LOW_forks, VERY_LOW_commits
# Support: 0.8825065274151436
# Confidence: 0.9159891598915988
# Lift: 1.0348786083731043
#
# Rule: MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_commiters
# Support: 0.391644908616188
# Confidence: 0.974025974025974
# Lift: 1.047898730483
#
# Rule: MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks
# Support: 0.391644908616188
# Confidence: 0.9933774834437086
# Lift: 1.0338684134753815
#
# Rule: MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_commiters -> VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.9933774834437086
# Lift: 1.031066602056749
#
# Rule: MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_commits
# Support: 0.391644908616188
# Confidence: 0.9615384615384616
# Lift: 1.0462194055944056
#
# Rule: MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_stars -> VERY_LOW_commiters, VERY_LOW_forks
# Support: 0.391644908616188
# Confidence: 0.967741935483871
# Lift: 1.0620205194565118
#
# Rule: MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.967741935483871
# Lift: 1.0529692082111437
#
# Rule: MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.967741935483871
# Lift: 1.0182559376107765
#
# Rule: MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_stars -> VERY_LOW_commiters, VERY_LOW_commits
# Support: 0.391644908616188
# Confidence: 0.9036144578313253
# Lift: 1.000243749564733
#
# Rule: MEDIUM_RATE, VERY_LOW_commiters, VERY_LOW_stars -> VERY_LOW_forks, VERY_LOW_commits
# Support: 0.391644908616188
# Confidence: 0.9554140127388535
# Lift: 1.0668325564984866
#
# Rule: MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commiters -> VERY_LOW_commits, VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.9554140127388535
# Lift: 1.057582563234049
#
# Rule: VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commiters
# Support: 0.391644908616188
# Confidence: 0.4385964912280702
# Lift: 1.0433692927972105
#
# Rule: VERY_LOW_commiters, VERY_LOW_forks, VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.4424778761061947
# Lift: 1.0147845901118118
#
# Rule: VERY_LOW_commiters, VERY_LOW_forks, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commits
# Support: 0.391644908616188
# Confidence: 0.4310344827586207
# Lift: 1.0382780307959227
#
# Rule: MEDIUM_RATE, VERY_LOW_commits -> VERY_LOW_commiters, VERY_LOW_forks, VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.9433962264150944
# Lift: 1.0382780307959227
#
# Rule: MEDIUM_RATE, VERY_LOW_stars -> VERY_LOW_commiters, VERY_LOW_forks, VERY_LOW_commits
# Support: 0.391644908616188
# Confidence: 0.8982035928143712
# Lift: 1.0147845901118118
#
# Rule: MEDIUM_RATE, VERY_LOW_commiters -> VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.9316770186335405
# Lift: 1.0433692927972105
#
# Rule: VERY_LOW_commits, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commiters
# Support: 0.391644908616188
# Confidence: 0.4335260115606937
# Lift: 1.057582563234049
#
# Rule: VERY_LOW_forks, VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.43731778425655976
# Lift: 1.0668325564984866
#
# Rule: VERY_LOW_commiters, VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.4335260115606937
# Lift: 1.0002437495647332
#
# Rule: VERY_LOW_forks, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.391644908616188
# Confidence: 0.4120879120879121
# Lift: 1.0182559376107763
#
# Rule: VERY_LOW_commiters, VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commits
# Support: 0.391644908616188
# Confidence: 0.42613636363636365
# Lift: 1.0529692082111437
#
# Rule: VERY_LOW_commiters, VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.42979942693409745
# Lift: 1.0620205194565118
#
# Rule: VERY_LOW_commits -> MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.42613636363636365
# Lift: 1.0462194055944056
#
# Rule: VERY_LOW_stars -> MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_commiters
# Support: 0.391644908616188
# Confidence: 0.4065040650406504
# Lift: 1.031066602056749
#
# Rule: VERY_LOW_forks -> MEDIUM_RATE, VERY_LOW_commits, VERY_LOW_commiters, VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.4076086956521739
# Lift: 1.0338684134753815
#
# Rule: VERY_LOW_commiters -> MEDIUM_RATE, VERY_LOW_forks, VERY_LOW_commits, VERY_LOW_stars
# Support: 0.391644908616188
# Confidence: 0.4213483146067416
# Lift: 1.047898730483
